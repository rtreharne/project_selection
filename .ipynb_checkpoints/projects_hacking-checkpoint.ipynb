# %%
import pandas as pd
import string

# %%
df = pd.read_excel('allocations.xlsx')

# %%
df.head()
# Out:
#   Stu username Last  Name          First Name   Student ID  \
# 0     hltacton      Acton                 Tom  201105569.0
# 1     hlsahme6      Ahmed                Manu  201103055.0
# 2     hlrairey      Airey               Becca  201077645.0
# 3     hlmakber      Akber             Mehwish  201155581.0
# 4     pshalbad    Al Badi  Hajar Rashid Obaid  201079353.0
#
#             Stu Email               Other Email            Advisor  \
# 0  hltacton@liv.ac.uk        tacton95@gmail.com    Martin Mortimer
# 1  hlsahme6@liv.ac.uk   manuahmed@hotmail.co.uk    Dr Violaine See
# 2  hlrairey@liv.ac.uk  beccaairey@hotmail.co.uk      Samar Hasnain
# 3  hlmakber@liv.ac.uk        hlmakber@yahoo.com       See Violaine
# 4  pshalbad@liv.ac.uk     hajaralbadi@gmail.com  See, Violaine, Dr
#
#                               Programme  username Column1           Sup email  \
# 0            CZ00 – Biological Sciences    speedm     NaN    speedm@liv.ac.uk
# 1  C130 – Biological & Medical Sciences  greenhaf     NaN  greenhaf@liv.ac.uk
# 2                   C700 – Biochemistry  turnbull     NaN  turnbull@liv.ac.uk
# 3  C130 – Biological & Medical Sciences     tzech     NaN     tzech@liv.ac.uk
# 4  C130 – Biological & Medical Sciences   jonesar     NaN   jonesar@liv.ac.uk
#
#                               Both Email         Supervisor Topic Style  \
# 0    hltacton@liv.ac.uk,speedm@liv.ac.uk       Dr. M. Speed     1     B
# 1  hlsahme6@liv.ac.uk,greenhaf@liv.ac.uk   Dr. B. Greenhalf     1     L
# 2  hlrairey@liv.ac.uk,turnbull@liv.ac.uk  Prof. J. Turnbull     3     L
# 3     hlmakber@liv.ac.uk,tzech@liv.ac.uk        Dr. T. Zech     1     L
# 4   pshalbad@liv.ac.uk,jonesar@liv.ac.uk    Prof. A. Jones      1     B
#
#                                          Description
# 0  Topic 1: A systematic approach to convergent e...
# 1  Topic 1: Cell cycle determinants of chemothera...
# 2  Topic 3:  Topic 3: Heparan sulfate and Alzheim...
# 3  Topic 1: Axonal transport in hereditary spasti...
# 4  Topic 1: Bioinformatics related to proteomics ...

# %%
df['Style'] = df['Style'].str.replace(' ', '')
df['Style'] = df['Style'].str.replace('/', '')
df['Style'] = df['Style'].str.replace('Computer-baseddataanalysis', 'D')
df['Style'] = df['Style'].str.replace('Deskbased', 'D')
df['Style'] = df['Style'].str.replace('LabFieldandDry', 'LF')
df['Style'] = df['Style'].str.replace('Library', 'D')
df['Style'] = df['Style'].str.replace('+', '')
df['Style'] = df['Style'].str.replace('TBC', '')
df['Style'] = df['Style'].str.upper()

# %%
types = set(df['Style'])

# %%
types
# Out:
# {'',
#  'B',
#  'BL',
#  'BLM',
#  'BM',
#  'D',
#  'E',
#  'F',
#  'L',
#  'LB',
#  'LBF',
#  'LF',
#  'M',
#  'ME',
#  'ML',
#  'N',
#  'O',
#  'S',
#  'SL',
#  'Y',
#  nan}

# %%
style_dict = {'B': 'Bioinformatics',
              'L': 'Lab Work',
              'M': 'Medical',
              'D': 'Desk Based',
              'O': '?',
              'E': 'Educational',
              'S': 'Schools',
              'F': 'Field Work'}

# %%
group = df.groupby('Style').count()

# %%
group
# Out:
#        Stu username  Last  Name  First Name  Student ID  Stu Email  \
# Style
#                   1           1           1           1          1
# B                36          36          36          36         36
# BL                2           2           2           2          2
# BLM               1           1           1           1          1
# BM                3           3           3           3          3
# D                 7           7           7           7          7
# E                 2           2           2           2          2
# F                11          11          11          11         11
# L               182         182         182         182        182
# LB                4           4           4           4          4
# LBF               1           1           1           1          1
# LF                2           2           2           2          2
# M                24          24          24          24         24
# ME                1           1           1           1          1
# ML                2           2           2           2          2
# N                 1           1           1           1          1
# O                 5           5           5           5          5
# S                15          15          15          15         15
# SL                1           1           1           1          1
# Y                 1           1           1           1          1
#
#        Other Email  Advisor  Programme  username  Column1  Sup email  \
# Style
#                  1        1          1         1        0          1
# B               36       36         36        36        0         36
# BL               2        2          2         2        0          2
# BLM              1        1          1         1        0          1
# BM               3        3          3         3        0          3
# D                7        7          7         7        0          7
# E                2        2          2         2        0          2
# F               11       11         11        11        0         11
# L              182      180        182       182        7        182
# LB               4        4          4         4        0          4
# LBF              1        1          1         1        0          1
# LF               2        2          2         2        0          2
# M               24       24         24        24        0         24
# ME               1        1          1         1        0          1
# ML               2        2          2         2        0          2
# N                1        1          1         1        0          1
# O                5        5          5         5        0          5
# S               15       15         15        15        1         15
# SL               1        1          1         1        0          1
# Y                1        1          1         1        0          1
#
#        Both Email  Supervisor  Topic  Description
# Style
#                 1           1      1            1
# B              36          36     36           36
# BL              2           2      2            2
# BLM             1           1      1            1
# BM              3           3      3            3
# D               7           7      7            7
# E               2           2      2            2
# F              11          11     11           11
# L             182         182    182          182
# LB              4           4      4            4
# LBF             1           1      1            1
# LF              2           2      2            2
# M              24          24     24           24
# ME              1           1      1            1
# ML              2           2      2            2
# N               1           1      1            1
# O               5           5      5            5
# S              15          15     15           15
# SL              1           1      1            1
# Y               1           1      1            1

# %%
# define new dataframe base on primary type only
df3 = df

# %%
df3['Style'] = df3['Style'].astype(str).str[0]

# %%
group_primary = df3.groupby('Style').count()

# %%
group_f = group_primary['Topic']

# %%
dict(group_f)
# Out:
# {'B': 42,
#  'D': 7,
#  'E': 2,
#  'F': 11,
#  'L': 189,
#  'M': 27,
#  'N': 1,
#  'O': 5,
#  'S': 16,
#  'Y': 1,
#  'n': 9}

# %%
group_dict = dict(group_f)

# %%
del group_dict['n']
del group_dict['Y']
del group_dict['N']

# %%
group_dict
# Out:
# {'B': 42, 'D': 7, 'E': 2, 'F': 11, 'L': 189, 'M': 27, 'O': 5, 'S': 16}

# %%
cat = group_dict.keys()

# %%
val = group_dict.values()

# %%
pie(val, labels=cat, startangle=90)
axis('equal')
# Out:
# (-1.1112372185230868,
#  1.1112372185230868,
#  -1.1000000000000001,
#  1.1000000000000001)
